# %%
import pandas as pd

# %%
pd.read_csv("fitted_models_ridge.csv").query("muni_code == 101").head(50)
# Out:
#     Unnamed: 0  muni_code                                      pickled_model  \
# 0            0        101  b'\x80\x04\x95\xcd%\x00\x00\x00\x00\x00\x00\x8...
# 1            1        101                                                NaN
# 2            2        101                                                NaN
# 3            3        101                                                NaN
# 4            4        101                                                NaN
# 5            5        101                                                NaN
# 6            6        101                                                NaN
# 7            7        101                                                NaN
# 8            8        101                                                NaN
# 9            9        101                                                NaN
# 10          10        101                                                NaN
# ...
