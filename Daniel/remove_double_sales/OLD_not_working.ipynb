# %%
import pandas as pd
import time

# %%
# Replace 'your_file.csv' with the actual path to your CSV file
csv_file_path = 'processed_data_sales_1992_2022_161.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Now you can work with the DataFrame, for example, display the first few rows
len(df)
# Out:
# 9207

# %%
def find_matching_rows(df):
    matching_indices = set()
    checked_indices = set()

    for index, row in df.iterrows():
        if index in checked_indices:
            continue

        col1_value = row['date_of_sale']
        col2_prefix = row['address'].split()[0]  # Get the first word until whitespace

        matching_rows = df[
            (df['date_of_sale'] == col1_value) &
            (df['address'].str.split().str[0] == col2_prefix)
        ]

        matching_indices.update(matching_rows.index)
        checked_indices.update(matching_rows.index)

    return matching_indices

# %%
start_time = time.time()

matching_indices = find_matching_rows(df)
matching_df = df[df.index.isin(matching_indices)]

elapsed_time = time.time() - start_time
print(elapsed_time)
# Out:
# 93.50241088867188

# %%
print(len(matching_df))
matching_df.head(50)
# Out:
# 9207
#     municipality   housing_type                     address  zip_code  \
# 0            161  Ejerlejlighed        Dalvangsvej 13, 1. 3      2600
# 1            161  Ejerlejlighed              Kochsvej 5, st      2600
# 2            161  Ejerlejlighed               Kochsvej 5, 1      2600
# 3            161       Rækkehus               Anemonevej 27      2600
# 4            161          Villa               Statenevej 17      2600
# 5            161  Ejerlejlighed     Christiansvej 13, 2. th      2600
# 6            161          Villa               Blåmejsevej 1      2600
# 7            161  Ejerlejlighed          Gyvelvej 18, 1. tv      2600
# 8            161          Villa            Ejby Mosevej 143      2600
# 9            161          Villa                 Falkevej 30      2600
# 10           161          Villa              Rødkælkevej 47      2600
# 11           161          Villa              Ejbydalsvej 89      2600
# 12           161          Villa                 Edithsvej 9      2600
# 13           161          Villa                Ingersvej 30      2600
# 14           161  Ejerlejlighed  Brøndbyvestervej 20, st. 5      2600
# 15           161  Ejerlejlighed      Højvangsvej 30, st. tv      2600
# 16           161  Ejerlejlighed     Ørnebjergvej 12D, 2. th      2600
# 17           161  Ejerlejlighed     Christiansvej 7, st. th      2600
# 18           161          Villa               Byparkvej 121      2600
# 19           161          Villa               Byparkvej 121      2600
# 20           161  Ejerlejlighed    Sofielundsvej 1C, st. tv      2600
# 21           161       Rækkehus                Bovneager 25      2600
# 22           161  Ejerlejlighed   Brøndbyvestervej 18, 1. k      2600
# 23           161  Ejerlejlighed        Hovedvejen 146, 3. k      2600
# 24           161          Villa                 Falkevej 25      2600
# 25           161          Villa                Valmuevej 10      2600
# 26           161          Villa              Blåmejsevej 26      2600
# 27           161  Ejerlejlighed    Vestergårdsvej 23, 1. 59      2600
# 28           161          Villa              Ydergrænsen 16      2600
# 29           161  Ejerlejlighed   Brøndbyvestervej 10, 2. q      2600
# 30           161          Villa              Lunddalsvej 27      2600
# 31           161  Ejerlejlighed        Dalvangsvej 13, 1. 1      2600
# 32           161  Ejerlejlighed    Nordre Ringvej 10, 2. th      2600
# 33           161       Rækkehus                Bovneager 83      2600
# 34           161          Villa                 Spurvevej 9      2600
# 35           161       Rækkehus                Krogengen 13      2600
# 36           161       Rækkehus              Ejbysvinget 42      2600
# 37           161       Rækkehus             Stisager 7B, st      2600
# 38           161       Rækkehus               Stensbjerg 44      2600
# 39           161          Villa              Peders Kilde 8      2600
# 40           161          Villa              Tornskadevej 7      2600
# 41           161          Villa              Langagervej 24      2600
# 42           161          Villa                   Elmevej 2      2600
# 43           161          Villa               Duevej 11, st      2600
# 44           161       Rækkehus                 Ravnager 21      2600
# 45           161  Ejerlejlighed         Edithsvej 1B, 1. tv      2600
# 46           161       Rækkehus          Hvissingeparken 12      2600
# 47           161  Ejerlejlighed      Magnoliavej 18, st. tv      2600
# 48           161       Rækkehus               Anemonevej 19      2600
# 49           161       Rækkehus          Hvissingeparken 38      2600
#
#          town  purchase_amount date_of_sale type_of_sale  square meters  \
# 0    Glostrup          1000000   2022-12-28    Fam. Salg             88
# 1    Glostrup           600000   2022-12-28    Fam. Salg             99
# 2    Glostrup           600000   2022-12-28    Fam. Salg             73
# 3    Glostrup          3800000   2022-12-22    Alm. Salg            136
# 4    Glostrup          2900000   2022-12-22    Alm. Salg            121
# 5    Glostrup          1275000   2022-12-20    Alm. Salg             57
# 6    Glostrup          2400000   2022-12-20    Alm. Salg            132
# 7    Glostrup          2200000   2022-12-18    Alm. Salg             77
# 8    Glostrup          4350000   2022-12-18    Alm. Salg            139
# 9    Glostrup          4253000   2022-12-15    Alm. Salg            133
# 10   Glostrup          3850000   2022-12-12    Alm. Salg            136
# 11   Glostrup          3800000   2022-12-12    Alm. Salg            178
# 12   Glostrup          4200000   2022-12-12    Alm. Salg            142
# 13   Glostrup          3695000   2022-12-09    Alm. Salg             87
# 14   Glostrup          1575000   2022-12-07    Alm. Salg             72
# 15   Glostrup          1850000   2022-12-07    Alm. Salg             62
# 16   Glostrup          1300000   2022-12-03    Alm. Salg             53
# 17   Glostrup           871330   2022-12-01    Alm. Salg             79
# 18   Glostrup          2900000   2022-11-28    Alm. Salg            102
# 19   Glostrup          2900000   2022-11-28    Alm. Salg            199
# 20   Glostrup          1600000   2022-11-27    Alm. Salg             51
# 21   Glostrup          4525000   2022-11-22    Alm. Salg            135
# 22   Glostrup          1900000   2022-11-22    Alm. Salg             80
# 23   Glostrup          1470000   2022-11-22    Alm. Salg             68
# 24   Glostrup          3525000   2022-11-22    Alm. Salg             99
# 25   Glostrup          2550000   2022-11-22    Alm. Salg            114
# 26   Glostrup          2910000   2022-11-14    Alm. Salg             96
# 27   Glostrup          1475000   2022-11-13    Alm. Salg             53
# 28   Glostrup          3900000   2022-11-12    Alm. Salg            177
# 29   Glostrup          1875000   2022-11-06    Alm. Salg             80
# 30   Glostrup          3000000   2022-11-06    Alm. Salg             78
# 31   Glostrup          1150000   2022-11-03    Alm. Salg             44
# 32   Glostrup          1395000   2022-11-02    Alm. Salg             57
# 33   Glostrup          3600000   2022-11-01    Alm. Salg            106
# 34   Glostrup          3800000   2022-11-01    Alm. Salg             87
# 35   Glostrup          3650000   2022-10-30    Alm. Salg             85
# 36   Glostrup          4050000   2022-10-30    Alm. Salg            135
# 37   Glostrup          2336000   2022-10-29    Fam. Salg            150
# 38   Glostrup          3600000   2022-10-26    Fam. Salg            131
# 39   Glostrup          2440960   2022-10-13    Alm. Salg            152
# 40   Glostrup          7640000   2022-10-11    Alm. Salg            186
# 41   Glostrup          2125000   2022-10-11    Fam. Salg            202
# 42   Glostrup          4235000   2022-10-05    Alm. Salg            101
# 43   Glostrup          1670000   2022-10-03    Fam. Salg            159
# 44   Glostrup          3600000   2022-09-29    Alm. Salg            100
# 45   Glostrup          2595000   2022-09-28    Alm. Salg             84
# 46   Glostrup          3575000   2022-09-27    Alm. Salg             98
# 47   Glostrup          1550000   2022-09-19    Alm. Salg             51
# 48   Glostrup          3900000   2022-09-18    Alm. Salg            136
# 49   Glostrup          3100000   2022-09-18    Alm. Salg             98
#
#     square meters_price  rooms  year_of_construction  \
# 0                 11364      3                  1967
# 1                  6061      3                  1906
# 2                  8219      3                  1906
# 3                 27941      4                  1974
# 4                 23967      4                  1979
# 5                 22368      2                  1947
# 6                 16667      7                  1957
# 7                 28571      3                  1961
# 8                 31295      5                  1980
# 9                 31977      5                  1939
# 10                28309      5                  1963
# 11                21348      5                  1972
# 12                29577      5                  1934
# 13                42471      4                  1937
# 14                21875      2                  1961
# 15                29839      2                  1934
# 16                24528      2                  1935
# 17                11029      4                  1947
# 18                28431      4                  1959
# 19                14573      6                  2023
# 20                31373      2                  1939
# 21                33519      5                  2012
# 22                23750      3                  1961
# 23                21618      2                  1966
# 24                35606      4                  1938
# 25                22368      3                  1930
# 26                30313      3                  1962
# 27                27830      1                  1970
# 28                22034      5                  1969
# 29                23438      3                  1961
# 30                38462      5                  1931
# 31                26136      1                  1967
# 32                24474      2                  1940
# 33                33962      4                  2013
# 34                43678      3                  1955
# 35                42941      3                  2003
# 36                30000      5                  2008
# 37                15573      4                  2015
# 38                27481      4                  2003
# 39                16059      5                  1969
# 40                41075      6                  2019
# 41                10520      6                  1956
# 42                41931      4                  1935
# 43                10503      7                  1957
# 44                36000      4                  1964
# 45                30893      3                  1944
# 46                36480      4                  1967
# 47                30392      2                  1946
# 48                28676      4                  1973
# 49                31633      3                  1967
#
#    The percentage difference between the latest bid price and the sale price
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 -5%
# 4                                                 -9%
# 5                                                 -9%
# 6                                                 -8%
# 7                                                 NaN
# 8                                                 -7%
# 9                                                 NaN
# 10                                                -8%
# 11                                                -5%
# 12                                                -4%
# 13                                                NaN
# 14                                                -7%
# 15                                                -7%
# 16                                                -4%
# 17                                                NaN
# 18                                                -9%
# 19                                                -9%
# 20                                                NaN
# 21                                                -4%
# 22                                                -9%
# 23                                                -2%
# 24                                                -5%
# 25                                                -2%
# 26                                                -3%
# 27                                                -5%
# 28                                                -9%
# 29                                                NaN
# 30                                                -9%
# 31                                               -12%
# 32                                                NaN
# 33                                                -5%
# 34                                                -4%
# 35                                                -5%
# 36                                                -3%
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                -4%
# 41                                                NaN
# 42                                                -6%
# 43                                                NaN
# 44                                               -10%
# 45                                                NaN
# 46                                                -6%
# 47                                                NaN
# 48                                                -2%
# 49                                               -11%
